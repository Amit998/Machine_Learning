# %%
pip list
# Out:
# Package                          Version               Location
# -------------------------------- --------------------- ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -xml                             4.5.2
# absl-py                          0.10.0
# aiofiles                         0.6.0
# aiohttp                          3.7.4.post0
# altair                           4.1.0
# apache-beam                      2.28.0
# appdirs                          1.4.3
# argon2-cffi                      20.1.0
# asgiref                          3.2.5
# astor                            0.8.1
# astroid                          2.4.2
# astunparse                       1.6.3
# async-timeout                    3.0.1
# atomicwrites                     1.4.0
# attrdict                         2.0.1
# attrs                            20.3.0
# audioread                        2.1.9
# ...
